# %%
df = pd.read_csv("tweet.csv")

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 
  
# Reads 'Youtube04-Eminem.csv' file  

comment_words = ' '
stopwords = set(STOPWORDS) 
print(stopwords)
  
# iterate through the csv file 
for val in df['Tweet']: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
# Out:
# {'being', 'doing', 'herself', "shouldn't", 'ourselves', 'between', 'the', 'where', "couldn't", 'no', 'him', 'com', "won't", 'with', "she'd", 'by', "i've", 'ever', 'up', 'k', 'was', 'here', 'just', 'be', 'ours', 'have', "you'd", "we'd", "you've", 'but', 'for', "hadn't", "hasn't", 'of', "weren't", 'over', "how's", 'www', 'it', "they'd", 'on', "let's", "don't", 'some', 'what', 'yours', 'however', 'itself', 'theirs', 'a', 'this', "what's", 'is', 'those', "wouldn't", 'his', 'until', "she's", 'that', 'own', 'its', "you'll", 'how', 'too', 'cannot', 'he', 'there', "who's", 'been', 'after', "it's", 'only', 'yourself', 'since', 'from', "here's", 'else', "they'll", 'i', 'such', 'few', "i'd", "they've", 'our', 'each', 'himself', 'r', "i'm", 'under', "where's", 'having', "when's", 'which', 'otherwise', "he'd", "why's", "i'll", "mustn't", 'so', 'about', 'does', 'themselves', "can't", 'had', 'shall', 'am', 'off', "that's", "didn't", 'hers', 'their', "aren't", 'would', 'while', 'as', 'whom', 'against', 'if', "he'll", "we've", 'through', "they're", 'any', 'who', "isn't", 'her', 'me', 'them', 'you', 'my', 'again', 'has', 'these', 'do', "she'll", 'also', 'or', 'and', 'because', "haven't", 'out', 'myself', 'they', 'can', 'get', 'to', 'not', "there's", 'other', 'into', 'down', 'in', 'she', 'below', 'during', 'further', "wasn't", "we'll", 'why', 'most', 'like', 'same', 'nor', 'yourselves', 'ought', 'were', "he's", 'we', 'should', "you're", "doesn't", 'more', 'an', 'all', 'are', 'http', 'before', 'than', 'then', 'when', 'at', 'your', 'above', "shan't", 'both', 'very', "we're", 'did', 'once', 'could'}

# %%
df.head()
# Out:
#                              Tweet
# 0   DianeEMeier: New Guidelines: E
# 1   DianeEMeier: New Guidelines: E
# 2   DianeEMeier: New Guidelines: E
# 3   DianeEMeier: New Guidelines: E
# 4   DianeEMeier: New Guidelines: E

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 1 columns):
# Tweet    85 non-null object
# dtypes: object(1)
# memory usage: 760.0+ bytes

# %%
df['Tweet']
# Out:
# 0                        DianeEMeier: New Guidelines: E
# 1                        DianeEMeier: New Guidelines: E
# 2                        DianeEMeier: New Guidelines: E
# 3                        DianeEMeier: New Guidelines: E
# 4                        DianeEMeier: New Guidelines: E
# 5                                     New Guidelines: E
# 6     Credit card U.S. yield reaches a new high amon...
# 7     Tired of the hype around blockchain? Here's a ...
# 8                            INCREDIBLE way to go #JPM
# 9     #JPMorgan Chase &amp; Co Bank Might Run a Pilo...
# 10    #JPM Coin, by jpmorgan may be launched by this...
# 11                                                Tweet
# 12     WeissRatings: #JPMorgan Chase is to start tri...
# 13     WeissRatings: #JPMorgan Chase is to start tri...
# 14     WeissRatings: #JPMorgan Chase is to start tri...
# 15               JAMVILAHABARI: TODAY IN TIMES OBSERVER
# 16                              TODAY IN TIMES OBSERVER
# 17    #ihatejunkmail and so do # investors Chase jam...
# 18     WeissRatings: #JPMorgan Chase is to start tri...
# 19    Chase volume for U.S. credit cards rose nearly...
# 20     WeissRatings: #JPMorgan Chase is to start tri...
# 21     WeissRatings: #JPMorgan Chase is to start tri...
# 22    The United States' largest bank, #JPMorgan Cha...
# 23     WeissRatings: #JPMorgan Chase is to start tri...
# 24                                               GoodTe
# 25    Credit Card PDV Slips &amp; Slides Among Big 6...
# 26     WeissRatings: #JPMorgan Chase is to start tri...
# 27    #JPMorgan Chase is to start trials of its #JPM...
# 28    JPMorgan to Start Customer Trials of Its 'JPM ...
# 29                                            JP Morgan
#                             ...
# 55     WeissRatings: A #JPMorgan analyst has admitte...
# 56                           MCI ELITE JAGUAR-HOPE TEAM
# 57     Goldbroker_com: Could JPMorgan Chase Be Hit w...
# 58     aidourtroops: 14-June2019 jimcramer #StopTrad...
# 59    14-June2019 jimcramer #StopTrading #alert " $J...
# 60     WeissRatings: A #JPMorgan analyst has admitte...
# 61     WeissRatings: A #JPMorgan analyst has admitte...
# 62     WeissRatings: A #JPMorgan analyst has admitte...
# 63     WeissRatings: A #JPMorgan analyst has admitte...
# 64     WeissRatings: A #JPMorgan analyst has admitte...
# 65     WeissRatings: A #JPMorgan analyst has admitte...
# 66     WeissRatings: A #JPMorgan analyst has admitte...
# 67    And we all laughed at #JPM coin until Facebook...
# 68     WeissRatings: A #JPMorgan analyst has admitte...
# 69     WeissRatings: A #JPMorgan analyst has admitte...
# 70     WeissRatings: A #JPMorgan analyst has admitte...
# 71     WeissRatings: A #JPMorgan analyst has admitte...
# 72     WeissRatings: A #JPMorgan analyst has admitte...
# 73     WeissRatings: A #JPMorgan analyst has admitte...
# 74     WeissRatings: A #JPMorgan analyst has admitte...
# 75     WeissRatings: A #JPMorgan analyst has admitte...
# 76     WeissRatings: A #JPMorgan analyst has admitte...
# 77     WeissRatings: A #JPMorgan analyst has admitte...
# 78     WeissRatings: A #JPMorgan analyst has admitte...
# 79     WeissRatings: A #JPMorgan analyst has admitte...
# 80     WeissRatings: A #JPMorgan analyst has admitte...
# 81     WeissRatings: A #JPMorgan analyst has admitte...
# 82     WeissRatings: A #JPMorgan analyst has admitte...
# 83     WeissRatings: A #JPMorgan analyst has admitte...
# 84     WeissRatings: A #JPMorgan analyst has admitte...
# Name: Tweet, Length: 85, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 1 columns):
# Tweet    85 non-null object
# dtypes: object(1)
# memory usage: 760.0+ bytes
