# %%
text = open('chinese.txt', 'r',encoding= 'UTF-8-sig').read()

# %%
text
# Out:
# '人生难免会有失败。尽了全力，技不如人的失败，没有什么好遗憾的;最窝囊的失败，是当自己还有一搏的力气与机会时，却主动放弃了。L淘宝券优惠券的秒拍视频 \u200b\n9部风景优美的高分治愈电影推荐1. 小男孩 2. 海蒂和爷爷 3. 少年斯派维的奇异旅行 4. 我们天上见 5. 普罗旺斯的夏天 6. 奇迹 7. 蝴蝶 8. 小萝莉的猴神大叔 9. 月升王国 L全球旅拍杂志荐的秒拍视频 \u200b\n所以我选择了离开，并不是我实力不行，而是我相信成功不必过早。先不说我是否能够成为谁，就算我能成为他，我能火多久?我想，那个时候才是我最苦不堪言的时候吧。L淘宝天猫优惠券省钱必备的秒拍视频 \u200b\u200b\u200b\n【电商平台这样登上小学考卷，合适吗？】“苏宁、淘宝、拼多多、京东……打开手机，哪个应用程序不能购买这款防蚊扣？”近日，该涉及商业品牌植入的内容，出现在江苏南京栖霞区的小学语文期末考试卷上，有家长质疑：这是给电商品牌打广告。#小学试卷出现电商平台#，你咋看？O网页链接 \u200b  展开全文c\n今年6.18当日的三大电商App日活（DAU）对比：手机淘宝2.99亿，拼多多1.35亿，京东0.88亿。（Quest Mobile） \u200b\n#小学试卷出现电商平台#我觉得家长多想了，哪个小学生做完题目会兴致冲冲的告诉家乡，我想买维康防蚊扣？看说明书，写一句话广告语，本来就是语文应该教的东西，出现到试卷上也无可非议啊，至于电商平台，，这四个平台都出现了，觉得是给谁推广了？现在是，只要拼多多没意见就行，😂  \u200b  展开全文c\n#小学试卷出现电商平台#怎么就只能三个平台购买了，凭什么欺负人家拼多多 \u200b\n#小学试卷出现电商平台#南京市栖霞区的一张小学语文期末考试卷上试题，像是广告植入，这让家长咂舌不已。竟然还征集广告语！这一石好几鸟的操作太骚气。@淘宝 ，@京东 ，@苏宁易购 都能买到，咂舌的不应该是@拼多多 吗？ \u200b\n我妈，广场舞十级爱好者，拼多多资深用户，业余养生达人，技能：砍价，与陌生人闲聊至了解对方家族史，劝你将剩菜吃完 \u200b\n记得当时网上说：可以和拼多多灯牌媲美的，只有朱一龙的灯牌，别家艺人的灯牌都是分有颜色区分的，而朱一龙家的是五颜六色，色彩斑斓。\n最近过上了老年人的生活迷恋上了拼多多砍
# ...

# %%
import jieba
text = ' '.join(jieba.cut(text))
text
# Out:
# '人生 难免会 有 失败 。 尽 了 全力 ， 技不如人 的 失败 ， 没有 什么 好 遗憾 的 ; 最 窝囊 的 失败 ， 是 当 自己 还有 一搏 的 力气 与 机会 时 ， 却 主动 放弃 了 。 L 淘宝 券 优惠券 的 秒 拍 视频   \u200b \n 9 部 风景优美 的 高分 治愈 电影 推荐 1 .   小男孩   2 .   海蒂 和 爷爷   3 .   少年 斯派 维 的 奇异 旅行   4 .   我们 天上 见   5 .   普罗旺斯 的 夏天   6 .   奇迹   7 .   蝴蝶   8 .   小萝莉 的 猴神 大叔   9 .   月 升 王国   L 全球 旅拍 杂志 荐 的 秒 拍 视频   \u200b \n 所以 我 选择 了 离开 ， 并 不是 我 实力 不行 ， 而是 我 相信 成功 不必 过早 。 先不说 我 是否 能够 成为 谁 ， 就算 我能 成为 他 ， 我能 火 多久 ? 我 想 ， 那个 时候 才 是 我 最 苦不堪言 的 时候 吧 。 L 淘宝 天猫 优惠券 省钱 必备 的 秒 拍 视频   \u200b \u200b \u200b \n 【 电商 平台 这样 登上 小学 考卷 ， 合适 吗 ？ 】 “ 苏宁 、 淘宝 、 拼 多多 、 京东 … … 打开 手机 ， 哪个 应用程序 不能 购买 这款 防蚊扣 ？ ” 近日 ， 该 涉及 商业 品牌 植入 的 内容 ， 出现 在 江苏 南京 栖霞区 的 小学 语文 期末考试 卷上 ， 有 家长 质疑 ： 这 是 给 电商 品牌 打广告 。 # 小学 试卷 出现 电商 平台 # ， 你 咋 看 ？ O 网页 链接   \u200b     展开 全文 c \n 今年 6.18 当日 的 三大 电商 App 日活 （ DAU ） 对比 ： 手机 淘宝 2.99 亿 ， 拼 多多 1.35 亿 ， 京东 0.88 亿 。 （ Quest   Mobile ）   \u200b \n # 小学 试卷 出现 电商 平台 # 我 觉得 家长 多想 了 ， 哪个 小学生 做 完 题目 会 兴致 冲冲 的 告诉 家乡 ， 我 想 买 维康防 蚊扣 ？ 看 说明书 ， 写 一句 话 广告语 ， 本来 就是 语文 应该 教 的 东西 ， 出现 到 试卷 上 也 无可
# ...

# %%
from PIL import Image
import numpy as np
icon_path = 'back3.png'
icon = Image.open(icon_path).convert("RGBA")
mask = Image.new("RGBA", icon.size, (255,255,255))
mask.paste(icon,icon)
mask = np.array(mask)

# %%
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return tuple([255,255,255]) # RGB code of white color

# %%
from wordcloud import ImageColorGenerator
color_func = ImageColorGenerator(mask)

# %%
import random
from palettable.colorbrewer.sequential import YlGnBu_9 # choose the color set you like
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return tuple(YlGnBu_9.colors[random.randint(0,5)]) # we got 9 colors, so we generate random number from 0 to 8

# %%
font_path = 'SNsanafonGyou.ttf'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wc = WordCloud(font_path=font_path, background_color="black", max_words=2000, mask=mask,  min_font_size = 10, max_font_size=300, random_state=1)
wc.generate_from_text(text)
wc.recolor(color_func=color_func, random_state=2)
# save as png
output_path = 'wordcloud.png'
wc.to_file(output_path)
# display the word cloud
plt.rcParams["figure.figsize"] = (25,25)
plt.imshow(wc)
plt.axis("off")
plt.show()
